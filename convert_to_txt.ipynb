# %% [markdown]
# This jupyter notebook just converts the pdf files to text files and saves it in the same folder where the pdf files are located. Following functions have been taken directly from the Abhinav's code files.

# %%
pip install pdf2image
# Out:
# ...
#   Using cached pdf2image-1.16.0-py3-none-any.whl (10 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pytesseract
# Out:
# ...
#   Using cached pytesseract-0.3.10-py3-none-any.whl (14 kB)
# ...
#   Using cached packaging-21.3-py3-none-any.whl (40 kB)
# ...
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.0
#     Uninstalling packaging-21.0:
#       Successfully uninstalled packaging-21.0
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pdf2image import convert_from_path
from pytesseract import image_to_string
import pytesseract
import os

# %%
# Change the link in the os.listdir command to get all the files from a particular folder. Rest of the script will run fine without making any changes
# list_of_files = os.listdir(r"C:\Users\patelp21\Downloads\Code File\Code File\Format2\Format2")
# list_of_files = os.listdir(r"C:\Users\Prayag\Desktop\2007_to_2013\pdfs")
list_of_files = os.listdir(r"C:\Users\patelp21\Downloads\Code File\Code File\2007_to_2013\pdfs")

# %%
list_of_pdfs = [val for val in list_of_files if val.endswith(".pdf")]

# %%
list_of_pdfs[0][:8]
# Out:
# '00-01921'

# %%
pytesseract.pytesseract.tesseract_cmd = r"C:\Users\patelp21\AppData\Local\Tesseract-OCR\tesseract"

def convert_pdf_to_img(pdf_file):
    return convert_from_path(pdf_file)
#                             ,poppler_path= r'C:\Users\patelp21\Downloads\Code File\poppler-0.68.0_x86.7z\bin')

#poppler_path=r'C:\Program Files\poppler-0.68.0\bin'

def convert_image_to_text(file):
    
    text = image_to_string(file, config='--psm 11')
    #text = image_to_string(file)
    return text

def get_text_from_any_pdf(pdf_file):
    images = convert_pdf_to_img(pdf_file)
    final_text = ''
    for pg, img in enumerate(images):
        final_text += convert_image_to_text(img)
    return final_text

#path_to_pdf = 'scan-20121226.pdf'
# path_to_pdf = r'C:\Users\patelp21\Downloads\Code File\Code File\Scraping docs\42768.pdf'

# pdf_data = (get_text_from_any_pdf(path_to_pdf))

# %%
os.getcwd()
# Out:
# 'C:\\Users\\patelp21\\Downloads\\Code File\\Code File\\2007_to_2013'

# %%
os.chdir(r"C:\Users\patelp21\Downloads\Code File\Code File\2007_to_2013\txts")

# %%
for each_pdf in list_of_pdfs:
#     path_to_pdf = current_directory + '\\' + each_pdf
    try:
        pdf_data = (get_text_from_any_pdf(each_pdf))
    except:
        print("Could not convert")
        continue
    text_file = open(each_pdf[:8] +".txt", "w")
    n = text_file.write(pdf_data)
    text_file.close()
# Out:
# Could not convert
# Could not convert
# Could not convert
# Could not convert
# Could not convert
# Could not convert
# Could not convert
# Could not convert
# Could not convert
# Could not convert
# Could not convert
# Could not convert
# Could not convert
# Could not convert
# Could not convert
# Could not convert
# Could not convert
# Could not convert
# Could not convert
# Could not convert
# Could not convert
# Could not convert
# Could not convert
# Could not convert
# Could not convert
# Could not convert
# Could not convert
# Could not convert
# Could not convert
# Could not convert
# Could not convert
# Could not convert
# Could not convert
# Could not convert
# Could not convert
# Could not convert
# Could not convert
# Could not convert
# Could not convert
# Could not convert
# Could not convert
# Could not convert
# Could not convert
# Could not convert
# Could not convert
# Could not convert
# Could not convert
# Could not convert
# Could not convert
# Could not convert
# ...
